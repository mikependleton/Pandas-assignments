# %%
#2 Import the pandas package:
import pandas as pd

# %%
#3 Load the CSV file as a DataFrame:
file_url = 'https://raw.githubusercontent.com/PacktWorkshops/The-Pandas-Workshop/master/Chapter06/Data/student-mat.csv'
data_frame = pd.read_csv(file_url, delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-65483af881d2> in <module>
#       1 #3 Load the CSV file as a DataFrame:
#       2 file_url = 'https://raw.githubusercontent.com/PacktWorkshops/The-Pandas-Workshop/master/Chapter06/Data/student-mat.csv'
# ----> 3 data_frame = pd.read_csv(file_url, delimiter=';')
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     711
#     712     # open URLs
# --> 713     ioargs = _get_filepath_or_buffer(
#     714         path_or_buf,
#     715         encoding=encoding,
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     361         # assuming storage_options is to be interpreted as headers
#     362         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 363         with urlopen(req_info) as req:
#     364             content_encoding = req.headers.get("Content-Encoding", None)
#     365             if content_encoding == "gzip":
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     263     import urllib.request
#     264
# --> 265     return urllib.request.urlopen(*args, **kwargs)
#     266
#     267
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# c:\users\mikep\appdata\local\programs\python\python38-32\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
#4 Modify the DataFrame to contain only these columns:
#  “school”, “sex”, “age”, “address”, “heath”, “absences”, “G1”, “G2”, “G3”
data_frame = data_frame[[
    'school', 'sex', 'age', 'address', 'health', 'absences', 'G1', 'G2', 'G3'
]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-78093a833061> in <module>
#       1 #4 Modify the DataFrame to contain only these columns:
#       2 #  “school”, “sex”, “age”, “address”, “heath”, “absences”, “G1”, “G2”, “G3”
# ----> 3 data_frame = data_frame[[
#       4     'school', 'sex', 'age', 'address', 'health', 'absences', 'G1', 'G2', 'G3'
#       5 ]]
#
# NameError: name 'data_frame' is not defined

# %%
#5 Display the first 10 rows of the DataFrame:
data_frame.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a60c5b32749b> in <module>
#       1 #5 Display the first 10 rows of the DataFrame:
# ----> 2 data_frame.head(10)
#
# NameError: name 'data_frame' is not defined

# %%
#6 Build a pivot table indexed on "school":
pd.pivot_table(data_frame, index=['school'])
# Out:
#                G1         G2         G3  absences        age    health
# school
# GP      10.939828  10.782235  10.489971  5.965616  16.521490  3.575931
# MS      10.673913  10.195652   9.847826  3.760870  18.021739  3.391304

# %%
#7 Build a pivot table indexed on "school" and "age":
pd.pivot_table(data_frame, index=['school', 'age'])
# Out:
#                    G1         G2         G3   absences    health
# school age
# GP     15   11.231707  11.365854  11.256098   3.341463  3.585366
#        16   10.942308  11.182692  11.028846   5.451923  3.701923
#        17   10.802326  10.383721  10.232558   6.709302  3.639535
#        18   10.614035   9.964912   9.157895   7.333333  3.350877
#        19   11.222222  10.055556   9.055556  12.777778  3.277778
#        20   17.000000  18.000000  18.000000   0.000000  5.000000
#        22    6.000000   8.000000   8.000000  16.000000  1.000000
# MS     17   11.583333  11.166667  10.583333   4.666667  2.500000
#        18   10.960000  10.520000  10.440000   3.120000  3.640000
#        19    7.333333   6.833333   5.666667   3.500000  4.166667
#        20   12.000000  11.500000  12.000000   7.500000  3.500000
#        21   10.000000   8.000000   7.000000   3.000000  3.000000

# %%
#8 Build a pivot table indexed on "school", "sex" and "age"
#  with the mean and sum aggregation on the "absences" column:
pd.pivot_table(data_frame, index=['school', 'sex', 'age'], values = 'absences', aggfunc={'mean', 'sum'})
# Out:
#                      mean    sum
# school sex age
# GP     F   15    3.894737  148.0
#            16    5.888889  318.0
#            17    7.120000  356.0
#            18    8.137931  236.0
#            19   13.083333  157.0
#        M   15    2.863636  126.0
#            16    4.980000  249.0
#            17    6.138889  221.0
#            18    6.500000  182.0
#            19   12.166667   73.0
#            20    0.000000    0.0
#            22   16.000000   16.0
# MS     F   17    5.625000   45.0
#            18    1.785714   25.0
#            19    2.000000    4.0
#            20    4.000000    4.0
#        M   17    2.750000   11.0
#            18    4.818182   53.0
#            19    4.250000   17.0
#            20   11.000000   11.0
#            21    3.000000    3.0
